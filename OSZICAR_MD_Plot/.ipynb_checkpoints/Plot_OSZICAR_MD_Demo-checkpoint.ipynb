# %% [markdown]
# # Plot OSZICAR Script
# Plot_OSZICAR_MD.py is a Python script which allow to read and plot all quantites of OSZICAR VASP file.<br>
# Pylab package is needed for plotting.<br>
# [Script source](https://github.com/K4ys4r/VASP_Scripts/blob/master/OSZICAR_MD_Plot/Plot_OSZICAR_MD.py)

# %%
# %matplotlib inline

# %%
# %run Plot_OSZICAR_MD.py
# Out:
#           OSZICAR File Name ? > OSZICAR_MD
# T  : is the current temperature.
# E  : is the total free energy (including the kinetic energy of the ions and the energy of the Nosé thermostat).
# F  : is the total free energy  (at this point the energy of the reference atom has been subtracted).
# E0 : is the energy for sigma-> 0 .
# EK : is the kinetic energy.
# SP : is the potential energy of the Nosé thermostat.
# SK : is the corresponding kinetic energy.
#
#    more infos : https://cms.mpi.univie.ac.at/vasp/vasp/stdout_OSZICAR_file.html
#
# Yplot (T, E, F, E0, EK, SP or SK ) > T
#
# 	Mean  Temperature  = 321.018  (K)
# Plot Other Quantities (yes/no)? > yes
# Yplot (T, E, F, E0, EK, SP or SK ) > E
#
# 	Mean  Free Energy  = -1014.1083702  (eV)
# Plot Other Quantities (yes/no)? > yes
# Yplot (T, E, F, E0, EK, SP or SK ) > F
#
# 	Mean  Free Energy  = -1018.8802606  (eV)
# Plot Other Quantities (yes/no)? > yes
# Yplot (T, E, F, E0, EK, SP or SK ) > E0
#
# ...
